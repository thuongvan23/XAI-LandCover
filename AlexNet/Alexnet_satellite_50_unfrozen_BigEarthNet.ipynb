# %% [markdown]
# <a href="https://colab.research.google.com/github/thuongvan23/XAI-LandCover/blob/nhanLD/Alexnet_satellite_50_unfrozen_BigEarthNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.11/dist-packages (1.4.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.4.26)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.0.9)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Đường dẫn thư mục chứa ảnh đa phổ đã xử lý
data_dir = "/kaggle/input/bigearthnet-12band-10m/content/bigearthnet_12band_10m"

class_counts = {}
total_images = 0

for label in sorted(os.listdir(data_dir)):
    class_path = os.path.join(data_dir, label)
    if os.path.isdir(class_path):
        n_files = len([f for f in os.listdir(class_path) if f.endswith('.tif')])
        class_counts[label] = n_files
        total_images += n_files

# In kết quả
print("Số lượng ảnh mỗi class:")
for label, count in class_counts.items():
    print(f"Class {label}: {count} ảnh")

print(f"\nTổng số ảnh: {total_images}")
# Out:
# Số lượng ảnh mỗi class:
# Class S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP: 3305 ảnh
# Class S2A_MSIL2A_20170613T101031_N9999_R022_T34VER: 6686 ảnh
# Class S2A_MSIL2A_20170617T113321_N9999_R080_T29UPU: 7986 ảnh
# Class S2A_MSIL2A_20170701T093031_N9999_R136_T35VPK: 7997 ảnh
# Class S2A_MSIL2A_20170704T112111_N9999_R037_T29SND: 8216 ảnh
# Class S2A_MSIL2A_20170717T113321_N9999_R080_T29UPA: 370 ảnh
# Class S2A_MSIL2A_20170717T113321_N9999_R080_T29UPV: 6013 ảnh
# Class S2A_MSIL2A_20170720T100031_N9999_R122_T34UDG: 1540 ảnh
# Class S2A_MSIL2A_20170803T094031_N9999_R036_T34TCR: 4864 ảnh
# Class S2A_MSIL2A_20170813T112121_N9999_R037_T29SNC: 8222 ảnh
#
# Tổng số ảnh: 55199

# %%
import numpy as np
import rasterio
import matplotlib.pyplot as plt
import random

# Chọn ngẫu nhiên 1 class và 1 ảnh trong class
random_class = random.choice(os.listdir(data_dir))
img_path = os.path.join(data_dir, random_class)
random_img = random.choice([f for f in os.listdir(img_path) if f.endswith('.tif')])
img_full_path = os.path.join(img_path, random_img)

# Đọc ảnh
with rasterio.open(img_full_path) as src:
    img = src.read()  # shape: (12, H, W)

# In shape
print(f"Shape của ảnh {random_img}: {img.shape} (channels, height, width)")

# Hiển thị ảnh (dùng band 4,3,2 tương ứng RGB)
rgb = np.stack([img[3], img[2], img[1]], axis=-1)  # Chú ý chỉ số bắt đầu từ 0
rgb = rgb.astype(np.float32)
rgb /= np.max(rgb) + 1e-6  # Chuẩn hóa để hiển thị

plt.figure(figsize=(6, 6))
plt.imshow(rgb)
plt.title(f"{random_img} (class {random_class})")
plt.axis('off')
plt.show()
# Out:
# Shape của ảnh S2A_MSIL2A_20170803T094031_N9999_R036_T34TCR_58_35_12band.tif: (12, 120, 120) (channels, height, width)

# %%
import os
import random
from glob import glob
from sklearn.model_selection import train_test_split

# Gốc thư mục lưu các ảnh đã xử lý (12 band)
DATA_DIR = "/kaggle/input/bigearthnet-12band-10m/content/bigearthnet_12band_10m"

# Thiết lập tỉ lệ chia
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Đảm bảo tái lập kết quả
random.seed(42)

# Danh sách ảnh và nhãn
train_list = []
val_list = []
test_list = []

# Duyệt qua 10 class (0-9)
for class_label in sorted(os.listdir(DATA_DIR)):
    class_dir = os.path.join(DATA_DIR, class_label)
    if not os.path.isdir(class_dir):
        continue

    # Lấy tất cả ảnh .tif trong class
    image_paths = glob(os.path.join(class_dir, "*.tif"))
    if len(image_paths) < 5:
        continue  # bỏ qua nếu ít ảnh

    # Shuffle
    random.shuffle(image_paths)

    # Chia train/val/test
    train_images, temp = train_test_split(image_paths, train_size=train_ratio, random_state=42)
    val_images, test_images = train_test_split(temp, test_size=test_ratio / (val_ratio + test_ratio), random_state=42)

    # Gán nhãn
    # Nếu bạn chỉ cần giữ nhãn là tên folder (chuỗi)
    train_list.extend([(path, class_label) for path in train_images])
    val_list.extend([(path, class_label) for path in val_images])
    test_list.extend([(path, class_label) for path in test_images])


print(f"Số ảnh train: {len(train_list)}")
print(f"Số ảnh val: {len(val_list)}")
print(f"Số ảnh test: {len(test_list)}")
# Out:
# Số ảnh train: 38636
# Số ảnh val: 8280
# Số ảnh test: 8283

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose([
    # A.Normalize(mean=[0]*12, std=[1]*12, max_pixel_value=1.0),

    # A.Resize(244, 224),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5),
    A.Normalize(mean=0.0, std=1.0, max_pixel_value=1.0),
    ToTensorV2(transpose_mask=True),
])

val_transform = A.Compose([
    # A.Resize(224, 224),
    A.Normalize(mean=[0]*12, std=[1]*12, max_pixel_value=1.0),
    ToTensorV2(transpose_mask=False)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:87: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.11/dist-packages/albumentations/augmentations/transforms.py:239: RuntimeWarning: divide by zero encountered in reciprocal
#   self.denominator = np.reciprocal(

# %%
from torch.utils.data import Dataset
import torch
import tifffile as tiff

class BigEarthNetDataset(Dataset):
    def __init__(self, data_list, transform=None, label2index=None):
        self.data_list = data_list
        self.transform = transform
        self.label2index = label2index

    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, idx):
        img_path, label = self.data_list[idx]

        with rasterio.open(img_path) as src:
            image = src.read()  # (12, H, W)

        image = image.astype(np.float32) / 10000.0
        image = np.transpose(image, (1, 2, 0))  # (H, W, C)

        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        else:
            image = torch.tensor(np.transpose(image, (2, 0, 1)))

        label_idx = self.label2index[label]
        return image, label_idx

# %%
from torch.utils.data import DataLoader

# Batch size
BATCH_SIZE = 16

# Tạo ánh xạ label <-> index
label_set = sorted(set([label for _, label in train_list + val_list + test_list]))
label2index = {label: idx for idx, label in enumerate(label_set)}
index2label = {idx: label for label, idx in label2index.items()}
NUM_CLASSES = len(label2index)

# Dataset
train_dataset = BigEarthNetDataset(train_list, transform=train_transform, label2index=label2index)
val_dataset = BigEarthNetDataset(val_list, transform=val_transform, label2index=label2index)
test_dataset = BigEarthNetDataset(test_list, transform=val_transform, label2index=label2index)

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Lấy 1 mẫu bất kỳ từ train_dataset
sample_img, sample_label = train_dataset[0]

# Chuyển tensor về numpy để hiển thị
sample_img_np = sample_img.numpy().transpose(1, 2, 0)  # (H, W, C)

# Lấy lại các band RGB (band 4, 3, 2 --> index 3, 2, 1)
rgb = sample_img_np[:, :, [3, 2, 1]]

# Chuẩn hóa về [0, 1] nếu cần (nếu bạn đã normalize thì giá trị có thể lệch)
rgb = (rgb - rgb.min()) / (rgb.max() - rgb.min() + 1e-6)

import matplotlib.pyplot as plt
plt.imshow(rgb)
plt.title(f"Sample transformed image - label {sample_label}")
plt.axis("off")
plt.show()

# %%
# 1. Import cần thiết
import torch
import torch.nn as nn
from torchvision import models
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision.models import alexnet

# %%
# 2. Hàm tạo mô hình AlexNet cho 12 band

def get_finetuned_alexnet(num_classes=10, in_channels=12, pretrained=True):
    # 1. Load pretrained AlexNet
    model = models.alexnet(pretrained=pretrained)

    # 2. Replace first conv layer to accept 13-channel input
    old_conv = model.features[0]
    new_conv = nn.Conv2d(in_channels,
                         old_conv.out_channels,
                         kernel_size=old_conv.kernel_size,
                         stride=old_conv.stride,
                         padding=old_conv.padding)

    if in_channels > 3 and pretrained:
        with torch.no_grad():
            new_conv.weight[:, :3] = old_conv.weight
            new_conv.weight[:, 3:] = old_conv.weight[:, :1].repeat(1, in_channels - 3, 1, 1) * 0.01

    model.features[0] = new_conv

    # 3. Replace classifier head
    model.classifier = nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(256 * 6 * 6, 512),  # input features = 256 * 6 * 6
        nn.ReLU(inplace=True),
        nn.Dropout(0.5),
        nn.Linear(512, num_classes)
    )

    return model

# %%
# 3. EarlyStopping
class EarlyStopping:
    def __init__(self, patience=7, delta=0.001):
        self.patience = patience
        self.delta = delta
        self.counter = 0
        self.best_loss = float('inf')
        self.early_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# 4. Vòng lặp train/eval
def train_one_epoch(model, dataloader, optimizer, criterion, device):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * inputs.size(0)
        _, preds = outputs.max(1)
        correct += preds.eq(labels).sum().item()
        total += labels.size(0)
    return total_loss / total, correct / total

def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            _, preds = outputs.max(1)
            correct += preds.eq(labels).sum().item()
            total += labels.size(0)
    return total_loss / total, correct / total

# %%
def unfreeze_middle_50_alexnet(model):
    # Middle 50% feature layers: từ layer 3 đến layer 9
    for i in range(3, 10):
        for param in model.features[i].parameters():
            param.requires_grad = True

# %%
#5. TRAINING THE MODEL
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = get_finetuned_alexnet(num_classes=NUM_CLASSES, in_channels=12, pretrained=True).to(device)

# Step 1: Freeze toàn bộ mô hình trừ phần FC head
for param in model.parameters():
    param.requires_grad = False

for param in model.classifier.parameters():
    param.requires_grad = True

optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)
criterion = nn.CrossEntropyLoss()

def train_model(model, train_loader, val_loader, optimizer, criterion, device, epochs=50, unfreeze_epoch=10):
    early_stopping = EarlyStopping(patience=7, delta=0.001)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)

    for epoch in range(epochs):
        if epoch == unfreeze_epoch:
            print("Unfreezing middle 50% of AlexNet features for fine-tuning...")
            unfreeze_middle_50_alexnet(model)

            optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
            scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)

        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc = evaluate(model, val_loader, criterion, device)
        scheduler.step(val_loss)
        early_stopping(val_loss)

        print(f"Epoch {epoch+1}/{epochs}:")
        print(f"  Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
        print(f"  Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.4f}")
        print(f"  Learning Rate: {optimizer.param_groups[0]['lr']:.6f}")

        if early_stopping.early_stop:
            print("Early stopping triggered.")
            break

train_model(model, train_loader, val_loader, optimizer, criterion, device, epochs=50, unfreeze_epoch=10)
# Out:
# Epoch 1/50:
#   Train Loss: 1.4697 | Train Acc: 0.4576
#   Val   Loss: 1.1604 | Val   Acc: 0.5646
#   Learning Rate: 0.001000
# Epoch 2/50:
#   Train Loss: 1.3099 | Train Acc: 0.5124
#   Val   Loss: 1.1190 | Val   Acc: 0.6250
#   Learning Rate: 0.001000
# Epoch 3/50:
#   Train Loss: 1.2739 | Train Acc: 0.5278
#   Val   Loss: 1.0510 | Val   Acc: 0.6072
#   Learning Rate: 0.001000
# Epoch 4/50:
#   Train Loss: 1.2438 | Train Acc: 0.5409
#   Val   Loss: 1.0124 | Val   Acc: 0.6295
#   Learning Rate: 0.001000
# Epoch 5/50:
#   Train Loss: 1.2281 | Train Acc: 0.5448
#   Val   Loss: 0.9648 | Val   Acc: 0.6470
#   Learning Rate: 0.001000
# Epoch 6/50:
#   Train Loss: 1.2121 | Train Acc: 0.5503
#   Val   Loss: 0.9770 | Val   Acc: 0.6543
#   Learning Rate: 0.001000
# Epoch 7/50:
#   Train Loss: 1.2057 | Train Acc: 0.5539
#   Val   Loss: 0.9399 | Val   Acc: 0.6597
#   Learning Rate: 0.001000
# Epoch 8/50:
#   Train Loss: 1.1968 | Train Acc: 0.5598
#   Val   Loss: 0.9528 | Val   Acc: 0.6487
#   Learning Rate: 0.001000
# Epoch 9/50:
#   Train Loss: 1.1931 | Train Acc: 0.5606
#   Val   Loss: 0.9345 | Val   Acc: 0.6665
#   Learning Rate: 0.001000
# Epoch 10/50:
#   Train Loss: 1.1862 | Train Acc: 0.5627
#   Val   Loss: 1.0029 | Val   Acc: 0.6500
#   Learning Rate: 0.001000
# Unfreezing middle 50% of AlexNet features for fine-tuning...
# Epoch 11/50:
#   Train Loss: 0.7929 | Train Acc: 0.7140
#   Val   Loss: 0.5736 | Val   Acc: 0.8192
#   Learning Rate: 0.000100
# Epoch 12/50:
#   Train Loss: 0.5557 | Train Acc: 0.8078
#   Val   Loss: 0.4282 | Val   Acc: 0.8506
#   Learning Rate: 0.000100
# Epoch 13/50:
#   Train Loss: 0.4519 | Train Acc: 0.8461
#   Val   Loss: 0.3409 | Val   Acc: 0.8785
#   Learning Rate: 0.000100
# Epoch 14/50:
#   Train Loss: 0.3974 | Train Acc: 0.8671
#   Val   Loss: 0.3418 | Val   Acc: 0.8827
#   Learning Rate: 0.000100
# Epoch 15/50:
#   Train Loss: 0.3564 | Train Acc: 0.8786
#   Val   Loss: 0.3223 | Val   Acc: 0.8802
#   Learning Rate: 0.000100
# Epoch 16/50:
#   Train Loss: 0.3221 | Train Acc: 0.8905
#   Val   Loss: 0.2614 | Val   Acc: 0.9064
#   Learning Rate: 0.000100
# Epoch 17/50:
#   Train Loss: 0.2901 | Train Acc: 0.9011
#   Val   Loss: 0.2572 | Val   Acc: 0.9146
#   Learning Rate: 0.000100
# Epoch 18/50:
#   Train Loss: 0.2658 | Train Acc: 0.9070
#   Val   Loss: 0.2097 | Val   Acc: 0.9261
#   Learning Rate: 0.000100
# Epoch 19/50:
#   Train Loss: 0.2506 | Train Acc: 0.9126
#   Val   Loss: 0.2203 | Val   Acc: 0.9194
#   Learning Rate: 0.000100
# Epoch 20/50:
#   Train Loss: 0.2356 | Train Acc: 0.9191
#   Val   Loss: 0.2411 | Val   Acc: 0.9167
#   Learning Rate: 0.000100
# Epoch 21/50:
#   Train Loss: 0.2227 | Train Acc: 0.9219
#   Val   Loss: 0.2274 | Val   Acc: 0.9162
#   Learning Rate: 0.000100
# Epoch 22/50:
#   Train Loss: 0.2119 | Train Acc: 0.9271
#   Val   Loss: 0.1899 | Val   Acc: 0.9354
#   Learning Rate: 0.000100
# Epoch 23/50:
#   Train Loss: 0.2017 | Train Acc: 0.9288
#   Val   Loss: 0.2340 | Val   Acc: 0.9222
#   Learning Rate: 0.000100
# Epoch 24/50:
#   Train Loss: 0.1923 | Train Acc: 0.9329
#   Val   Loss: 0.1779 | Val   Acc: 0.9421
#   Learning Rate: 0.000100
# Epoch 25/50:
#   Train Loss: 0.1822 | Train Acc: 0.9369
#   Val   Loss: 0.1887 | Val   Acc: 0.9321
#   Learning Rate: 0.000100
# Epoch 26/50:
#   Train Loss: 0.1748 | Train Acc: 0.9398
#   Val   Loss: 0.1538 | Val   Acc: 0.9478
#   Learning Rate: 0.000100
# Epoch 27/50:
#   Train Loss: 0.1749 | Train Acc: 0.9384
#   Val   Loss: 0.1536 | Val   Acc: 0.9470
#   Learning Rate: 0.000100
# Epoch 28/50:
#   Train Loss: 0.1669 | Train Acc: 0.9436
#   Val   Loss: 0.1424 | Val   Acc: 0.9502
#   Learning Rate: 0.000100
# Epoch 29/50:
#   Train Loss: 0.1583 | Train Acc: 0.9451
#   Val   Loss: 0.1940 | Val   Acc: 0.9332
#   Learning Rate: 0.000100
# Epoch 30/50:
#   Train Loss: 0.1569 | Train Acc: 0.9444
#   Val   Loss: 0.1946 | Val   Acc: 0.9327
#   Learning Rate: 0.000100
# Epoch 31/50:
#   Train Loss: 0.1526 | Train Acc: 0.9470
#   Val   Loss: 0.1430 | Val   Acc: 0.9467
#   Learning Rate: 0.000100
# Epoch 32/50:
#   Train Loss: 0.1467 | Train Acc: 0.9486
#   Val   Loss: 0.1427 | Val   Acc: 0.9498
#   Learning Rate: 0.000050
# Epoch 33/50:
#   Train Loss: 0.1145 | Train Acc: 0.9602
#   Val   Loss: 0.1119 | Val   Acc: 0.9606
#   Learning Rate: 0.000050
# Epoch 34/50:
#   Train Loss: 0.1101 | Train Acc: 0.9614
#   Val   Loss: 0.1234 | Val   Acc: 0.9572
#   Learning Rate: 0.000050
# Epoch 35/50:
#   Train Loss: 0.1050 | Train Acc: 0.9636
#   Val   Loss: 0.1020 | Val   Acc: 0.9628
#   Learning Rate: 0.000050
# Epoch 36/50:
#   Train Loss: 0.1027 | Train Acc: 0.9632
#   Val   Loss: 0.1099 | Val   Acc: 0.9622
#   Learning Rate: 0.000050
# Epoch 37/50:
#   Train Loss: 0.1025 | Train Acc: 0.9644
#   Val   Loss: 0.1046 | Val   Acc: 0.9640
#   Learning Rate: 0.000050
# Epoch 38/50:
#   Train Loss: 0.0998 | Train Acc: 0.9646
#   Val   Loss: 0.1190 | Val   Acc: 0.9593
#   Learning Rate: 0.000050
# Epoch 39/50:
#   Train Loss: 0.0956 | Train Acc: 0.9671
#   Val   Loss: 0.1158 | Val   Acc: 0.9628
#   Learning Rate: 0.000025
# Epoch 40/50:
#   Train Loss: 0.0792 | Train Acc: 0.9720
#   Val   Loss: 0.0958 | Val   Acc: 0.9684
#   Learning Rate: 0.000025
# Epoch 41/50:
#   Train Loss: 0.0764 | Train Acc: 0.9742
#   Val   Loss: 0.0993 | Val   Acc: 0.9670
#   Learning Rate: 0.000025
# Epoch 42/50:
#   Train Loss: 0.0762 | Train Acc: 0.9736
#   Val   Loss: 0.0943 | Val   Acc: 0.9690
#   Learning Rate: 0.000025
# Epoch 43/50:
#   Train Loss: 0.0723 | Train Acc: 0.9741
#   Val   Loss: 0.1014 | Val   Acc: 0.9674
#   Learning Rate: 0.000025
# Epoch 44/50:
#   Train Loss: 0.0744 | Train Acc: 0.9740
#   Val   Loss: 0.0977 | Val   Acc: 0.9685
#   Learning Rate: 0.000025
# Epoch 45/50:
#   Train Loss: 0.0736 | Train Acc: 0.9746
#   Val   Loss: 0.0971 | Val   Acc: 0.9658
#   Learning Rate: 0.000025
# Epoch 46/50:
#   Train Loss: 0.0707 | Train Acc: 0.9754
#   Val   Loss: 0.0908 | Val   Acc: 0.9703
#   Learning Rate: 0.000025
# Epoch 47/50:
#   Train Loss: 0.0708 | Train Acc: 0.9754
#   Val   Loss: 0.0953 | Val   Acc: 0.9678
#   Learning Rate: 0.000025
# Epoch 48/50:
#   Train Loss: 0.0701 | Train Acc: 0.9744
#   Val   Loss: 0.1029 | Val   Acc: 0.9655
#   Learning Rate: 0.000025
# Epoch 49/50:
#   Train Loss: 0.0682 | Train Acc: 0.9758
#   Val   Loss: 0.1047 | Val   Acc: 0.9679
#   Learning Rate: 0.000025
# Epoch 50/50:
#   Train Loss: 0.0695 | Train Acc: 0.9751
#   Val   Loss: 0.0903 | Val   Acc: 0.9719
#   Learning Rate: 0.000025

# %%
#6. Đánh giá trên tập test
test_loss, test_acc = evaluate(model, test_loader, criterion, device)
print(f"\nTest Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 0.0760 | Test Acc: 0.9768

# %%
torch.save(model.state_dict(), "/kaggle/working/Alexnet_50_unfrozen_BigEarthNet.pth")
